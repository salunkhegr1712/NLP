# %%
# step 1 install basic requirement needed for web scrapping
# pip install requests
# pip install html5lib
# pip install bs4
# bs4 is beautifull_soap4 library

# %%
import requests
from bs4 import  BeautifulSoup

# %%
url="https://blog.hubspot.com/sales/famous-quotes"
# requests.get will fetch the website and print the results

r=requests.get(url)
# r.content will provide the content inside the body of returned html code

# %%
# now as we get r and it has something content init 
from distutils.command.install_egg_info import to_filename


htmlBeautified=BeautifulSoup(r.content,'html.parser')
htmlBeautified=htmlBeautified
print(htmlBeautified)
# so html5lib just do one thing here and that is to make html tree and parse the 
# html code and make it more modular and it is very much in view as compared to that of r.content file 
# which provide html in raw and unarranged manner
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en-us" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en-us" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en-us" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-us"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Meredith Hart" name="author"/>
# <meta content="In need of inspiration? We've compiled the 100 most famous quotes of all time to motivate you in your work and personal life. " name="description"/>
# <meta content="HubSpot" name="generator"/>
# <meta class="swiftype" content="Customer" data-type="string" name="doc-type"/>
# <meta class="swiftype" content="In need of inspiration? We've compiled the 100 most famous quotes of all time to motivate you in your work and personal life. " data-type="text" name="meta-description"/>
# <meta class="swiftype" content="2022-06-07" data-type="date" name="last-updated"/>
# <script nonce="8uc=" type="application/ld+json">
# 			{
# 			"@context": "https://schema.org",
# 			"@id": "https://blog.hubspot.com/sales/famous-quotes#article",
# 			"@type": "NewsArticle",
# 			"headline": "The 100 Most Famous Quotes of All Time",
# 			"image": [
# 				"https://www.hubspot.com/hubfs/most-famous-quotes-of-all-time.jpeg"
# 			],
# 			"datePublished": "2021-06-28T20:00:00+0000",
# 			"dateModified": "2022-06-07T15:56:29+0000",
# 			"author": {
# 				"@type": "Person",
# 				"name": "Meredith Hart",
# 				"url": "https://blog.hubspot.com/sales/author/meredith-hart"
# 			},
# 			"speakable": {
# 				"@type": "SpeakableSpecification",
# 				"xPath": ["//title", "/html/head/meta[@name='description']/@content"]
# 			},
# 			"publisher": {
# 				"@type": "Organization",
# 				"name": "HubSpot",
# 				"url": "https://www.hubspot.com",
# 				"logo": {
# 					"@type": "ImageObject",
# 					"url": "https://fs.hubspotusercontent00.net/hubfs/53/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Logos/HubSpot%20Logo%20112X112.svg",
# 					"width": 112,
# 					"height": 112
# 				},
# 				"sameAs": ["https://www.facebook.com/hubspot", "https://twitter.com/hubspot"]
# 			}
# 		}
#     </script>
# <title>The 100 Most Famous Quotes of All Time</title>
# <!-- exclude_hsg -->
# <link href="https://blog.hubspot.com/hubfs/HubSpot_Logos/HubSpot-Inversed-Favicon.png" rel="shortcut icon"/>
# <script nonce="8uc=" src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js"></script>
# <script nonce="8uc=">hsjQuery = window['jQuery'];</script>
# <meta content="In need of inspiration? We've compiled the 100 most famous quotes of all time to motivate you in your work and personal life. " property="og:description"/>
# <meta content="The 100 Most Famous Quotes of All Time" property="og:title"/>
# <meta content="In need of inspiration? We've compiled the 100 most famous quotes of all time to motivate you in your work and personal life. " name="twitter:description"/>
# <meta content="The 100 Most Famous Quotes of All Time" name="twitter:title"/>
# <style>
# a.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:'›';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}
# </style>
# <link href="https://blog.hubspot.com/wt-assets/static-files/2.0.13/core-nav/styles.css" rel="stylesheet"/>
# <link href="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/template_assets/58950231939/1659985523882/_Web_Team_Assets/Blog/assets/main.min.css" rel="stylesheet"/>
# <link href="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/template_assets/77591971379/1659985515324/_Web_Team_Assets/Blog/templates/partials/blog-international-navigation/navigation.min.css" rel="stylesheet"/>
# <link href="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/module_assets/77591971357/1659985512004/module_77591971357_read-time-bar.min.css" rel="stylesheet"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- Begin Domain Settings Code -->
# <meta content="app-id=587068814" name="apple-itunes-app"/>
# <meta content="HubSpot" name="twitter:app:name:iphone"/>
# <meta content="534167981" name="twitter:app:id:iphone"/>
# <meta content="Inbound Marketing" name="twitter:app:name:ipad"/>
# <meta content="587068814" name="twitter:app:id:ipad"/>
# <meta content="7f4fa0f1fccc171fd4d5af64f062521c" name="p:domain_verify"/>
# <meta content="”en-US”" http-equiv="”content-language”"/>
# <meta content="2IEWx1p87YR79mLbeeSi-osUja8cJtEvdo_CvCgzMtc" name="google-site-verification"/>
# <!-- isQA:   -->
# <meta content="#FF7A59" name="theme-color"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <!-- GDPR:  blog.hubspot.com | GTM-T7FPMN | build #(SizeLimitingPyMap: {hsg=2.0.13, legacy=4948}) -->
# <script data-gtm-id="GTM-T7FPMN" nonce="8uc=" src="https://blog.hubspot.com/wt-assets/static-files/compliance/index.js" type="text/javascript"></script>
# <!-- is_legacy_page: false -->
# <!-- exclude_globals: true -->
# <!-- test123: true || false -->
# <link href="https://blog.hubspot.com/wt-assets/static-files/2.0.13/blog-rebuild/styles.css" rel="stylesheet" type="text/css"/>
# <!-- HREFLANG MACRO -->
# <!-- Social Sharing -->
# <!-- End -->
# <!--Meta tag for Facebook Instant Articles-->
# <meta content="6039999393" property="fb:pages"/>
# <meta content="https://blog.hubspot.com/hubfs/most-famous-quotes-of-all-time.jpeg#keepProtocol" property="og:image"/>
# <meta content="598" property="og:image:width"/>
# <meta content="398" property="og:image:height"/>
# <meta content="Employee smiling after reading the most famous quotes of all time" property="og:image:alt"/>
# <meta content="https://blog.hubspot.com/hubfs/most-famous-quotes-of-all-time.jpeg#keepProtocol" name="twitter:image"/>
# <meta content="Employee smiling after reading the most famous quotes of all time" name="twitter:image:alt"/>
# <meta content="https://blog.hubspot.com/sales/famous-quotes" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@meredithlhart" name="twitter:creator"/>
# <link href="https://blog.hubspot.com/sales/famous-quotes" rel="canonical"/>
# <meta content="article" property="og:type"/>
# <link href="https://blog.hubspot.com/sales/rss.xml" rel="alternate" type="application/rss+xml"/>
# <meta content="blog.hubspot.com" name="twitter:domain"/>
# <meta content="@HubSpot" name="twitter:site"/>
# <meta content="en-us" http-equiv="content-language"/>
# <link href="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/template_assets/424655551/1593536412495/Custom/page/custom-stylemanager/No_Styling.min.css" rel="stylesheet"/>
# <script async="" nonce="8uc=" src="https://play.vidyard.com/embed/v4.js" type="text/javascript"></script>
# <meta name="twitter:label1" value="Reading time"/>
# <meta name="twitter:data1" value="9 min read"/>
# <link href="//static2cdn.hubspot.com/hubspot.com/static-1.4334/_hsg-ss/build/icons/hsg-icons.css" rel="stylesheet"/>
# <style type="text/css">
#       .hide {
#         display: none;
#       }
#
#
#       .blog-nav-top-bar .a11y-contrast-toggle,
#       .blog-nav-top-bar .a11y-contrast-enable {
#         padding-top: 3px;
#       }
#       .blog-nav-card__content--description.-small {
#         margin: 0;
#       }
#       .blog-nav-media-dropdown__stacked-list li p {
#         margin: 0;
#       }
#       .blog-nav .blog-nav-card h6 {
#         margin: 0;
#       }
#       .post-body__content .hs_cos_gallery_main .slick-dots li::before {
#         display: none;
#       }
#       .blog-search__modal-content.cl-modal-backdrop {
#         display: block;
#       }
#     </style>
# <!-- Closing Head Tag -->
# </head>
# <!-- english_lang: true -->
# <body class="wt-blog wt-blog__subpages hs-content-id-6120243620 hs-blog-post hs-content-path-sales-famous-quotes hs-content-name-the-100-most-famous-quotes-of-all-time hs-blog-name-sales hs-blog-id-279673741 hs-blog-lang-en" is-listing-template="false" style="">
# <div class="header-container-wrapper">
# <div class="header-container container-fluid">
# <div class="row-fluid-wrapper row-depth-1 row-number-1">
# <div class="row-fluid">
# <div class="span12 widget-span widget-type-global_group" data-w="12" data-widget-type="global_group" data-x="0" style="">
# <div data-fixed-element="placeholder">
# <header class="blog-nav blog-nav__wrapper" data-fixed-element="target" id="blog-nav-global">
# <nav aria-label="Utility Navigation" class="blog-nav-top-bar">
# <div class="container cl-page-width">
# <a class="blog-nav-menu__skip-link cl-button -tertiary -small" href="#blog-main-content">Skip to content</a>
# <ul class="links">
# <li class="link-item">
# <button aria-checked="false" class="a11y-contrast-toggle" role="switch">
# <span class="a11y-contrast-enable">
# <svg aria-hidden="true" height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd"><circle class="a11y-contrast-enable-icon" cx="8" cy="8" r="8"></circle><path class="a11y-contrast-enable-inner" d="M8 14A6 6 0 118 2z"></path></g></svg>        Enable High Contrast
#       </span>
# <span class="a11y-contrast-disable">
# <svg aria-hidden="true" height="16" width="16" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><circle cx="8" cy="8" fill="" r="8"></circle><path d="M11,5 C14.3137085,5 17,7.6862915 17,11 L17,11 L5,11 L5.00413847,10.7750617 C5.12242824,7.56557489 7.76160306,5 11,5 Z" fill="#FFF" transform="translate(11.000000, 8.000000) rotate(90.000000) translate(-11.000000, -8.000000)"></path></g></svg>
#         Disable High Contrast
#       </span>
# </button>
# </li>
# <li class="link-item--has-dropdown blog-nav__group-item--has-dropdown">
# <button aria-controls="language-submenu-53" aria-expanded="false" class="cl-navLink cl-link -light -hasSubNav link-item--anchor">
# <svg aria-hidden="true" class="blog-nav__globe-icon cl-icon language-icon"><use fill="currentColor" xlink:href="#languages"></use></svg>
#   English
#   <svg aria-hidden="true" class="cl-icon dropdown-arrow">
# <use xlink:href="#down"></use>
# </svg>
# </button>
# <ul class="dropdown-container cl-card-caret -white -top-right -border" id="language-submenu-53">
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="ja">日本語</a>
# </li>
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="de">Deutsch</a>
# </li>
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="en">English</a>
# </li>
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="es">Español</a>
# </li>
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="pt">Português</a>
# </li>
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="fr">Français</a>
# </li>
# </ul>
# </li>
# <li class="link-item--has-dropdown blog-nav__group-item--has-dropdown">
# <button aria-controls="about-dropdown-submenu" aria-expanded="false" class="cl-navLink cl-link -light -hasSubNav link-item--anchor">
#               About HubSpot
#               <svg aria-hidden="true" class="cl-icon dropdown-arrow">
# <use xlink:href="#down"></use>
# </svg>
# </button>
# <ul class="dropdown-container cl-card-caret -white -top-right -border -wide" id="about-dropdown-submenu">
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link" href="https://www.hubspot.com/our-story">About Us</a>
# </li>
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link" href="https://www.hubspot.com/company/contact">Contact Us</a>
# </li>
# <li class="cl-dropdown-menu-item link-item--dropdown-menu-item">
# <a class="cl-dropdown-menu-link -light redirect-link" href="https://help.hubspot.com/">Customer Support</a>
# </li>
# </ul>
# </li>
# <li class="link-item">
# <a class="cl-navLink cl-link -light -hasSubNav link-item--anchor" data-logged-in-href="//app.hubspot.com/home" data-logged-in-text="Go to my account" href="//app.hubspot.com/home">
#           Log in
#         </a>
# </li>
# <li>
# <a class="blog-nav-hs-products__cta cl-button -small -primary" href="https://www.hubspot.com/products/get-started">Start free or get a demo</a>
# </li>
# </ul>
# </div>
# </nav>
# <nav aria-label="HubSpot Blog Navigation" class="blog-nav-menu">
# <div class="hsg-page-width-normal">
# <div class="blog-nav__inner">
# <div class="blog-nav__inner--top-bar">
# <a aria-label="HubSpot" class="blog-nav__logo" href="/" id="blog-nav__logo">
# <img alt="" class="blog-nav__logo-mobile" height="32" id="blog-nav__logo-mobile" loading="lazy" src="https://blog.hubspot.com/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Icons/Sprocket.svg" width="30"/>
# <img alt="" class="blog-nav__logo-fixed" height="30" id="blog-nav__logo-fixed" loading="lazy" src="https://blog.hubspot.com/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Logos/HubSpot%20Logo.svg" width="85"/>
# <img alt="" class="blog-nav__logo-desktop" height="23" id="blog-nav__logo-desktop" loading="lazy" src="https://blog.hubspot.com/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Logos/HubSpot%20Logo.svg" width="84"/>
# </a>
# <button class="blog-nav__logo-caret" id="blog-nav__logo-caret">
# <svg alt="Left caret to go back to home view" aria-hidden="true" class="cl-icon menu-arrow-icon">
# <use xlink:href="#left"></use>
# </svg>
# <span class="blog-nav__logo-caret-home" id="blog-nav__logo-caret-home">Menu</span>
# </button>
# <div class="blog-nav__group-item--search-container">
# <form data-nav-search-form="">
# <label class="blog-nav__search-field">
# <input aria-label="Search..." name="search-term" placeholder="Search..." type="text"/>
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#search"></use>
# </svg>
# </label>
# </form>
# </div>
# <div class="blog-nav__burger-wrapper">
# <button aria-controls="burger-submenu" aria-expanded="false" aria-label="Main menu" class="blog-nav__burger">
# <span class="blog-nav__burger-label"></span>
# </button>
# </div>
# </div>
# <div class="blog-nav__groups-wrapper" id="burger-submenu">
# <div class="blog-nav-primary-links">
# <ul class="blog-nav-primary-links__list blog-nav__group blog-nav__group--primary">
# <li class="blog-nav-primary-links__list-item -dropdown blog-nav__group-item blog-nav__group-item--has-dropdown">
# <button aria-controls="blogs-mega-menu-submenu" aria-expanded="false" class="blog-nav-primary-links__link-wrapper blog-nav__link-wrapper blog-nav__link">
# <div class="blog-nav-primary-links__link">
#         Blogs
#         <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#down"></use>
# </svg>
# </div>
# </button>
# <div class="blog-nav__dropdown-list blog-nav-mega-menu" id="blogs-mega-menu-submenu">
# <section class="blog-nav-mega-menu__section blog-nav-mega-menu__section--dark">
# <div class="cl-page-width">
# <div class="blog-nav-media-dropdown">
# <div class="blog-nav-media-dropdown--mobile">
# <p class="blog-nav-media-dropdown--mobile-header">Blogs</p>
# <ul class="blog-nav-media-dropdown__card-grid">
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-marketing" gtm="" href="https://blog.hubspot.com/marketing" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Marketing
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-sales" gtm="" href="https://blog.hubspot.com/sales" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Sales
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-service" gtm="" href="https://blog.hubspot.com/service" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Service
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-website" gtm="" href="https://blog.hubspot.com/website" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Website
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://blog.hubspot.com/the-hustle" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           The Hustle
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# </ul>
# <a class="blog-nav-media-dropdown--mobile-cta cl-button -regular -primary" href="https://blog.hubspot.com/" target="_blank">See all blogs</a>
# </div>
# <div class="blog-nav-media-dropdown--desktop">
# <div class="blog-nav-media-dropdown__card-list-wrapper">
# <ul class="blog-nav-media-dropdown__card-grid blog-nav-media-dropdown__card-grid--column-3">
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-marketing" gtm="" href="https://blog.hubspot.com/marketing" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__thumbnail">
# <img alt="" height="32" sizes="(max-width: 32px) 100vw, 32px" src="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogMarketing_64x64.png?width=32&amp;height=32&amp;name=BlogMarketing_64x64.png" srcset="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogMarketing_64x64.png?width=16&amp;height=16&amp;name=BlogMarketing_64x64.png 16w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogMarketing_64x64.png?width=32&amp;height=32&amp;name=BlogMarketing_64x64.png 32w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogMarketing_64x64.png?width=48&amp;height=48&amp;name=BlogMarketing_64x64.png 48w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogMarketing_64x64.png?width=64&amp;height=64&amp;name=BlogMarketing_64x64.png 64w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogMarketing_64x64.png?width=80&amp;height=80&amp;name=BlogMarketing_64x64.png 80w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogMarketing_64x64.png?width=96&amp;height=96&amp;name=BlogMarketing_64x64.png 96w" width="32"/>
# </div>
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Marketing
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm="">Read world-renowned marketing content to help grow your audience</p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-sales" gtm="" href="https://blog.hubspot.com/sales" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__thumbnail">
# <img alt="" height="32" sizes="(max-width: 32px) 100vw, 32px" src="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogSales_64x64.png?width=32&amp;height=32&amp;name=BlogSales_64x64.png" srcset="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogSales_64x64.png?width=16&amp;height=16&amp;name=BlogSales_64x64.png 16w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogSales_64x64.png?width=32&amp;height=32&amp;name=BlogSales_64x64.png 32w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogSales_64x64.png?width=48&amp;height=48&amp;name=BlogSales_64x64.png 48w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogSales_64x64.png?width=64&amp;height=64&amp;name=BlogSales_64x64.png 64w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogSales_64x64.png?width=80&amp;height=80&amp;name=BlogSales_64x64.png 80w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogSales_64x64.png?width=96&amp;height=96&amp;name=BlogSales_64x64.png 96w" width="32"/>
# </div>
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Sales
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm="">Read best practices and examples of how to sell smarter
#
# </p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-service" gtm="" href="https://blog.hubspot.com/service" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__thumbnail">
# <img alt="" height="32" sizes="(max-width: 32px) 100vw, 32px" src="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogService_64x64.png?width=32&amp;height=32&amp;name=BlogService_64x64.png" srcset="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogService_64x64.png?width=16&amp;height=16&amp;name=BlogService_64x64.png 16w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogService_64x64.png?width=32&amp;height=32&amp;name=BlogService_64x64.png 32w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogService_64x64.png?width=48&amp;height=48&amp;name=BlogService_64x64.png 48w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogService_64x64.png?width=64&amp;height=64&amp;name=BlogService_64x64.png 64w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogService_64x64.png?width=80&amp;height=80&amp;name=BlogService_64x64.png 80w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogService_64x64.png?width=96&amp;height=96&amp;name=BlogService_64x64.png 96w" width="32"/>
# </div>
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Service
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm="">Read expert tips on how to build a customer-first organization
#
# </p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-website" gtm="" href="https://blog.hubspot.com/website" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__thumbnail">
# <img alt="" height="32" sizes="(max-width: 32px) 100vw, 32px" src="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogWebsite_64x64.png?width=32&amp;height=32&amp;name=BlogWebsite_64x64.png" srcset="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogWebsite_64x64.png?width=16&amp;height=16&amp;name=BlogWebsite_64x64.png 16w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogWebsite_64x64.png?width=32&amp;height=32&amp;name=BlogWebsite_64x64.png 32w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogWebsite_64x64.png?width=48&amp;height=48&amp;name=BlogWebsite_64x64.png 48w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogWebsite_64x64.png?width=64&amp;height=64&amp;name=BlogWebsite_64x64.png 64w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogWebsite_64x64.png?width=80&amp;height=80&amp;name=BlogWebsite_64x64.png 80w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/BlogWebsite_64x64.png?width=96&amp;height=96&amp;name=BlogWebsite_64x64.png 96w" width="32"/>
# </div>
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Website
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm="">Read tips and tutorials on how to build better websites</p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://blog.hubspot.com/the-hustle" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__thumbnail">
# <img alt="" height="32" src="https://blog.hubspot.com/hubfs/assets/hubspot.com/web-team/WBZ/HubSpot%20Media/Blog%202021/Images/Nav/Optimized/TheHustle_Icon_Dark.svg" width="32"/>
# </div>
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           The Hustle
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm="">Read the latest business and tech news</p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# </ul>
# <div>
# <a class="cl-button -small -primary" href="https://blog.hubspot.com/" target="_blank">See all blogs</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </li>
# <li class="blog-nav-primary-links__list-item -dropdown blog-nav__group-item blog-nav__group-item--has-dropdown">
# <button aria-controls="newsletters-mega-menu-submenu" aria-expanded="false" class="blog-nav-primary-links__link-wrapper blog-nav__link-wrapper blog-nav__link">
# <div class="blog-nav-primary-links__link">
#         Newsletters
#         <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#down"></use>
# </svg>
# </div>
# </button>
# <div class="blog-nav__dropdown-list blog-nav-mega-menu" id="newsletters-mega-menu-submenu">
# <section class="blog-nav-mega-menu__section blog-nav-mega-menu__section--dark">
# <div class="cl-page-width">
# <div class="blog-nav-media-dropdown">
# <div class="blog-nav-media-dropdown--mobile">
# <p class="blog-nav-media-dropdown--mobile-header">Newsletters</p>
# <ul class="blog-nav-media-dropdown__card-grid">
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://thehustle.co/?utm_medium=referral&amp;utm_source=blognavcard-newsletters-hustle" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           The Hustle<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="blog-nav-media-dropdown--desktop">
# <div class="blog-nav-media-dropdown__card-list-wrapper">
# <ul class="blog-nav-media-dropdown__card-grid blog-nav-media-dropdown__card-grid--column-3">
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://thehustle.co/?utm_medium=referral&amp;utm_source=blognavcard-newsletters-hustle" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__thumbnail">
# <img alt="" height="32" src="https://blog.hubspot.com/hubfs/assets/hubspot.com/web-team/WBZ/HubSpot%20Media/Blog%202021/Images/Nav/Optimized/TheHustle_Icon_Dark.svg" width="32"/>
# </div>
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           The Hustle<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm="">Get the latest business and tech news in five minutes or less</p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </li>
# <li class="blog-nav-primary-links__list-item -dropdown blog-nav__group-item blog-nav__group-item--has-dropdown">
# <button aria-controls="videos-mega-menu-submenu" aria-expanded="false" class="blog-nav-primary-links__link-wrapper blog-nav__link-wrapper blog-nav__link">
# <div class="blog-nav-primary-links__link">
#         Videos
#         <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#down"></use>
# </svg>
# </div>
# </button>
# <div class="blog-nav__dropdown-list blog-nav-mega-menu" id="videos-mega-menu-submenu">
# <section class="blog-nav-mega-menu__section blog-nav-mega-menu__section--dark">
# <div class="cl-page-width">
# <div class="blog-nav-media-dropdown">
# <div class="blog-nav-media-dropdown--mobile">
# <p class="blog-nav-media-dropdown--mobile-header">Videos</p>
# <ul class="blog-nav-media-dropdown__card-grid">
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://www.youtube.com/channel/UCaAx1xeTgF3rs4rBPDq6-Kw?utm_medium=referral&amp;utm_source=blognavcard-videos-hsyoutube" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           HubSpot YouTube<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://www.youtube.com/channel/UCVeuau7DLrg7zlAjxxDbdww?utm_medium=referral&amp;utm_source=hsblognavcard-videos-hsmarketingyoutube" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           HubSpot Marketing YouTube<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://www.youtube.com/channel/UCyaN6mg5u8Cjy2ZI4ikWaug?utm_medium=referral&amp;utm_source=hsblognavcard-videos-myfirstmillionyoutube" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           My First Million YouTube
#
# <svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="blog-nav-media-dropdown--desktop">
# <div class="blog-nav-media-dropdown__card-list-wrapper">
# <ul class="blog-nav-media-dropdown__card-grid blog-nav-media-dropdown__card-grid--column-3">
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://www.youtube.com/channel/UCaAx1xeTgF3rs4rBPDq6-Kw?utm_medium=referral&amp;utm_source=blognavcard-videos-hsyoutube" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__thumbnail">
# <img alt="" height="32" sizes="(max-width: 32px) 100vw, 32px" src="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/HubSpotLogo_64x64.png?width=32&amp;height=32&amp;name=HubSpotLogo_64x64.png" srcset="https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/HubSpotLogo_64x64.png?width=16&amp;height=16&amp;name=HubSpotLogo_64x64.png 16w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/HubSpotLogo_64x64.png?width=32&amp;height=32&amp;name=HubSpotLogo_64x64.png 32w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/HubSpotLogo_64x64.png?width=48&amp;height=48&amp;name=HubSpotLogo_64x64.png 48w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/HubSpotLogo_64x64.png?width=64&amp;height=64&amp;name=HubSpotLogo_64x64.png 64w, https://blog.hubspot.com/hs-fs/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Nav/Optimized/HubSpotLogo_64x64.png?width
target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Entrepreneurs on Fire
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-podcasts-idigress" gtm="" href="https://listen.hubspot.com/public/83/iDigress-with-Troy-Sandidge-a413039c" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           iDigress
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-podcasts-martechpodcast" gtm="" href="https://listen.hubspot.com/public/83/MarTech-Podcast-%2F%2F-Marketing-%2B-Technology-%3D-Business-Growth-5b86063f" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           MarTech Podcast
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-podcasts-businessmadesimple" gtm="" href="https://listen.hubspot.com/public/83/Business-Made-Simple-with-Donald-Miller-6279d097" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Business Made Simple
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# ...
# </li>
# </ul>
# </section>
# <section class="hsg-footer__nav-column">
# <h2 class="hsg-footer__nav-heading">
# <button aria-disabled="true" class="hsg-footer__nav-toggle" tabindex="-1">Partners</button>
# </h2>
# <ul><li class="hsg-footer__nav-item" data-order="0">
# <a data-linkorder="0" data-order="0" href="https://www.hubspot.com/partners">All Partner Programs</a>
# </li>
# <li class="hsg-footer__nav-item" data-order="1">
# <a data-linkorder="1" data-order="1" href="https://www.hubspot.com/partners/solutions">Solutions Partner Program</a>
# </li>
# <li class="hsg-footer__nav-item" data-order="2">
# <a data-linkorder="2" data-order="2" href="https://www.hubspot.com/partners/app">App Partner Program</a>
# </li>
# <li class="hsg-footer__nav-item" data-order="3">
# <a data-linkorder="3" data-order="3" href="https://www.hubspot.com/startups/partners">HubSpot for Startups</a>
# </li>
# <li class="hsg-footer__nav-item" data-order="4">
# <a data-linkorder="4" data-order="4" href="https://www.hubspot.com/partners/affiliates">Affiliate Program</a>
# </li>
# </ul>
# </section>
# </div>
# </div>
# </nav>
# </div>
# <section class="hsg-footer__contact-links">
# <ul class="hsg-footer__social">
# <li>
# <a class="hstc_facebook" href="https://www.facebook.com/hubspot" target="_blank">
# <i class="hsg-icon hsg-icon-facebook"></i><span class="hidden-social">Facebook</span>
# </a>
# </li>
# <li>
# <a class="hstc_instagram" href="https://www.instagram.com/hubspot/" target="_blank">
# <i class="hsg-icon hsg-icon-instagram"></i><span class="hidden-social">Instagram</span>
# </a>
# </li>
# <li>
# <a class="hstc_youtube" href="https://youtube.com/user/HubSpot" target="_blank">
# <i class="hsg-icon hsg-icon-youtube"></i><span class="hidden-social">Youtube</span>
# </a>
# </li>
# <li>
# <a class="hstc_twitter" href="https://twitter.com/HubSpot" target="_blank">
# <i class="hsg-icon hsg-icon-twitter"></i><span class="hidden-social">Twitter</span>
# </a>
# </li>
# <li>
# <a class="hstc_linkedin" href="https://www.linkedin.com/company/hubspot" target="_blank">
# <i class="hsg-icon hsg-icon-linkedin"></i><span class="hidden-social">Linkedin</span>
# </a>
# </li>
# <li>
# <a class="hstc_medium" href="https://medium.com/@HubSpot" target="_blank">
# <i class="hsg-icon hsg-icon-medium"></i><span class="hidden-social">Medium</span>
# </a>
# </li>
# </ul>
# </section>
# <section class="hsg-footer__bottom">
# <div class="hsg-footer__apps">
# <a class="hsg-footer__app" href="https://apps.apple.com/us/app/hubspot/id1107711722">
# <img alt="Download on the App Store" class="homepage-mobile-footer-apple" loading="lazy" src="https://blog.hubspot.com/hubfs/app%20store%20high%20res.png"/>
# </a>
# <a class="hsg-footer__app" href="https://play.google.com/store/apps/details?id=com.hubspot.android&amp;hl=en_US">
# <img alt="Get it on Google Play" class="homepage-mobile-footer-google" loading="lazy" src="https://blog.hubspot.com/hubfs/google%20play%20high%20res.png"/>
# </a>
# </div>
# <div class="hsg-footer__logo">
# <a href="//www.hubspot.com">
# <img alt="HubSpot" loading="lazy" src="https://blog.hubspot.com/hubfs/WBZ-1165%20Global%20Nav%20Redesign/Wordmark-White.svg"/></a>
# <p>Copyright © 2021 HubSpot, Inc.</p>
# </div>
# <div class="hsg-footer__copyright">
# <ul>
# <li><a href="https://legal.hubspot.com/legal-stuff">Legal Stuff</a></li>
# <li><a href="https://legal.hubspot.com/privacy-policy">Privacy Policy</a></li>
# <li><a href="https://legal.hubspot.com/security">Security</a></li>
# </ul>
# </div>
# </section>
# </footer>
# <script nonce="8uc=" src="https://blog.hubspot.com/wt-assets/static-files/2.0.13/core-nav/scripts.js"></script>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
# </div>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
# <div class="row-fluid-wrapper row-depth-1 row-number-2">
# <div class="row-fluid">
# <div class="span12 widget-span widget-type-raw_html" data-w="12" data-widget-type="raw_html" data-x="0" style="">
# <div class="cell-wrapper layout-widget-wrapper">
# <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_raw_html" data-hs-cos-general-type="widget" data-hs-cos-type="raw_html" id="hs_cos_wrapper_module_1497301113455132" style=""><!-- prev 4208 -->
# <script nonce="8uc=" src="https://blog.hubspot.com/wt-assets/static-files/2.0.13/blog-rebuild/scripts.js"></script></span>
# </div><!--end layout-widget-wrapper -->
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
# </div><!--end footer -->
# </div><!--end footer wrapper -->
# <script nonce="8uc=">
# (function () {
#     window.addEventListener('load', function () {
#         setTimeout(function () {
#             var xhr = new XMLHttpRequest();
#             xhr.open('POST', '/_hcms/perf', true /*async*/);
#             xhr.setRequestHeader("Content-type", "application/json");
#             xhr.onreadystatechange = function () {
#                 // do nothing.
#             };
#             var connection = navigator.connection || navigator.mozConnection || navigator.webkitConnection;
#             function populateNetworkInfo(name, connection, info) {
#                 if (name in connection) {
#                     info[name] = connection[name];
#                 }
#             }
#             var networkInfo = {};
#             if (connection) {
#                 ['type', 'effectiveType', 'downlink', 'rtt'].forEach(function(name) {
#                     populateNetworkInfo(name, connection, networkInfo);
#                 });
#             }
#             var perfData = {
#                 url: location.href,
#                 portal: 53,
#                 content: 6120243620,
#                 group: -1,
#                 connection: networkInfo,
#                 timing: performance.timing
#             };
#             xhr.send(JSON.stringify(perfData));
#         }, 3000);  // Execute this 3 seconds after onload.
#     });
# })();
# </script>
# <script nonce="8uc=" src="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/template_assets/80991207740/1659535990527/_Web_Team_Assets/Component_Modules/assets/icons.min.js"></script>
# <script nonce="8uc=">
# var hsVars = hsVars || {}; hsVars['language'] = 'en-us';
# </script>
# <script nonce="8uc=" src="/hs/hsstatic/cos-i18n/static-1.53/bundles/project.js"></script>
# <script nonce="8uc=" src="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/template_assets/56723797352/1659985523186/_Web_Team_Assets/Blog/assets/main.min.js"></script>
# <script nonce="8uc=" src="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/template_assets/61924670007/1659985520346/_Web_Team_Assets/Blog/assets/vendors.min.js"></script>
# <script nonce="8uc=" src="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/module_assets/77591971357/1659985511185/module_77591971357_read-time-bar.min.js"></script>
# <script nonce="8uc=" src="https://blog.hubspot.com/hs-fs/hub/53/hub_generated/template_assets/77591971381/1659985520313/_Web_Team_Assets/Blog/templates/partials/blog-international-navigation/navigation.min.js"></script>
# <!--[if lte IE 8]>
#     <script charset="utf-8" src="https://js.hsforms.net/forms/v2-legacy.js"></script>
#     <![endif]-->
# <script data-hs-allowed="true" nonce="8uc=" src="/_hcms/forms/v2.js"></script>
# <script data-hs-allowed="true" nonce="8uc=">
#         var options = {
#             portalId: '53',
#             formId: '438f4c23-5908-4c4e-a9a7-e30a3897211b',
#             formInstanceId: '2847',
#             pageId: '6120243620',
#             region: 'na1',
#
#
#
#
#             pageName: "The 100 Most Famous Quotes of All Time",
#
#
#
#
#
#
#             css: '',
#             target: '#hs_form_target_cro_blog_expanding_form',
#
#
#
#
#
#             contentType: "blog-post",
#
#
#             formsBaseUrl: '/_hcms/forms/',
#
#
#
#             formData: {
#                 cssClass: 'hs-form stacked hs-custom-form'
#             }
#         };
#
#         options.getExtraMetaDataBeforeSubmit = function() {
#             var metadata = {};
#
#
#             if (hbspt.targetedContentMetadata) {
#                 var count = hbspt.targetedContentMetadata.length;
#                 var targetedContentData = [];
#                 for (var i = 0; i < count; i++) {
#                     var tc = hbspt.targetedContentMetadata[i];
#                      if ( tc.length !== 3) {
#                         continue;
#                      }
#                      targetedContentData.push({
#                         definitionId: tc[0],
#                         criterionId: tc[1],
#                         smartTypeId: tc[2]
#                      });
#                 }
#                 metadata["targetedContentMetadata"] = JSON.stringify(targetedContentData);
#             }
#
#             return metadata;
#         };
#
#         hbspt.forms.create(options);
#     </script>
# <script data-hs-allowed="true" nonce="8uc=">
#         var options = {
#             portalId: '53',
#             formId: '438f4c23-5908-4c4e-a9a7-e30a3897211b',
#             formInstanceId: '6601',
#             pageId: '6120243620',
#             region: 'na1',
#
#
#
#
#             pageName: "The 100 Most Famous Quotes of All Time",
#
#
#
#
#
#
#             css: '',
#             target: '#hs_form_target_cro_blog_expanding_form-1660287992651',
#
#
#
#
#
#             contentType: "blog-post",
#
#
#             formsBaseUrl: '/_hcms/forms/',
#
#
#
#             formData: {
#                 cssClass: 'hs-form stacked hs-custom-form'
#             }
#         };
#
#         options.getExtraMetaDataBeforeSubmit = function() {
#             var metadata = {};
#
#
#             if (hbspt.targetedContentMetadata) {
#                 var count = hbspt.targetedContentMetadata.length;
#                 var targetedContentData = [];
#                 for (var i = 0; i < count; i++) {
#                     var tc = hbspt.targetedContentMetadata[i];
#                      if ( tc.length !== 3) {
#                         continue;
#                      }
#                      targetedContentData.push({
#                         definitionId: tc[0],
#                         criterionId: tc[1],
#                         smartTypeId: tc[2]
#                      });
#                 }
#                 metadata["targetedContentMetadata"] = JSON.stringify(targetedContentData);
#             }
#
#             return metadata;
#         };
#
#         hbspt.forms.create(options);
#     </script>
# <script data-hs-allowed="true" nonce="8uc=">
#         var options = {
#             portalId: '53',
#             formId: '438f4c23-5908-4c4e-a9a7-e30a3897211b',
#             formInstanceId: '4992',
#             pageId: '6120243620',
#             region: 'na1',
#
#
#
#
#             pageName: "The 100 Most Famous Quotes of All Time",
#
#
#
#
#
#
#             css: '',
#             target: '#hs_form_target_blog_sticky_footer_form',
#
#
#
#
#
#             contentType: "blog-post",
#
#
#             formsBaseUrl: '/_hcms/forms/',
#
#
#
#             formData: {
#                 cssClass: 'hs-form stacked hs-custom-form'
#             }
#         };
#
#         options.getExtraMetaDataBeforeSubmit = function() {
#             var metadata = {};
#
#
#             if (hbspt.targetedContentMetadata) {
#                 var count = hbspt.targetedContentMetadata.length;
#                 var targetedContentData = [];
#                 for (var i = 0; i < count; i++) {
#                     var tc = hbspt.targetedContentMetadata[i];
#                      if ( tc.length !== 3) {
#                         continue;
#                      }
#                      targetedContentData.push({
#                         definitionId: tc[0],
#                         criterionId: tc[1],
#                         smartTypeId: tc[2]
#                      });
#                 }
#                 metadata["targetedContentMetadata"] = JSON.stringify(targetedContentData);
#             }
#
#             return metadata;
#         };
#
#         hbspt.forms.create(options);
#     </script>
# <script data-hs-allowed="true" nonce="8uc=">
#         var options = {
#             portalId: '53',
#             formId: 'f3507b84-ad3e-4df5-97a5-72550ac2860c',
#             formInstanceId: '8213',
#             pageId: '6120243620',
#             region: 'na1',
#
#
#
#
#             pageName: "The 100 Most Famous Quotes of All Time",
#
#
#
#
#
#
#             css: '',
#             target: '#hs_form_target_download_for_later',
#
#
#
#
#
#             contentType: "blog-post",
#
#
#             formsBaseUrl: '/_hcms/forms/',
#
#
#
#             formData: {
#                 cssClass: 'hs-form stacked hs-custom-form'
#             }
#         };
#
#         options.getExtraMetaDataBeforeSubmit = function() {
#             var metadata = {};
#
#
#             if (hbspt.targetedContentMetadata) {
#                 var count = hbspt.targetedContentMetadata.length;
#                 var targetedContentData = [];
#                 for (var i = 0; i < count; i++) {
#                     var tc = hbspt.targetedContentMetadata[i];
#                      if ( tc.length !== 3) {
#                         continue;
#                      }
#                      targetedContentData.push({
#                         definitionId: tc[0],
#                         criterionId: tc[1],
#                         smartTypeId: tc[2]
#                      });
#                 }
#                 metadata["targetedContentMetadata"] = JSON.stringify(targetedContentData);
#             }
#
#             return metadata;
#         };
#
#         hbspt.forms.create(options);
#     </script>
# <!-- Start of HubSpot Analytics Code -->
# <script nonce="8uc=" type="text/javascript">
# var _hsq = _hsq || [];
# _hsq.push(["setContentType", "blog-post"]);
# _hsq.push(["setCanonicalUrl", "https:\/\/blog.hubspot.com\/sales\/famous-quotes"]);
# _hsq.push(["setPageId", "6120243620"]);
# _hsq.push(["setContentMetadata", {
#     "contentPageId": 6120243620,
#     "legacyPageId": "6120243620",
#     "contentFolderId": null,
#     "contentGroupId": 279673741,
#     "abTestId": null,
#     "languageVariantId": 6120243620,
#     "languageCode": "en-us",
#
# }]);
# </script>
# <script async="" defer="" id="hs-script-loader" nonce="8uc=" src="/hs/scriptloader/53.js" type="text/javascript"></script>
# <!-- End of HubSpot Analytics Code -->
# <script nonce="8uc=" type="text/javascript">
# var hsVars = {
#     ticks: 1660287992473,
#     page_id: 6120243620,
#
#     content_group_id: 279673741,
#     portal_id: 53,
#     app_hs_base_url: "https://app.hubspot.com",
#     cp_hs_base_url: "https://cp.hubspot.com",
#     language: "en-us",
#     analytics_page_type: "blog-post",
#     analytics_page_id: "6120243620",
#     category_id: 3,
#     folder_id: 0,
#     is_hubspot_user: false
# }
# </script>
# <script defer="" nonce="8uc=" src="/hs/hsstatic/HubspotToolsMenu/static-1.138/js/index.js"></script>
# <!-- HREFLANG MACRO -->
# <script nonce="8uc=" src="//cdn-3.convertexperiments.com/js/10031559-1003891.js"></script>
# <!-- wt-mktg-analytics script -->
# <script nonce="8uc=" src="https://blog.hubspot.com/wt-assets/static-files/mktg-analytics/bundle.min.js?1173" type="text/javascript"></script>
# <!-- test234: true -->
# <script nonce="8uc=" src="//blog.hubspot.com/wt-assets/static-files/2611/messaging-functions/scripts.js" type="text/javascript"></script>
# <script nonce="8uc=" src="https://static.hsappstatic.net/affiliates-landing-embed/ex/referral.js" type="text/javascript"></script>
# </body></html>

# %%
# find will only return 1st exact match but the finadll function will return an whole array of elememnts 
# related to that one perticular search value 

print(type(htmlBeautified))
# will return all possible paragraphs tags which are present in the htmlBeautified 
a=htmlBeautified.find_all('p')
# return all the anchor tags which are present in HTML file 
b=htmlBeautified.find_all('a')
# for i in range(len(a)):
#     print(a[i].get_text());
#     # print(a[i]["class"])

print("one part ended and another is going to happed next\n")

for m in b:
    print(m.get_text())
# Out:
# <class 'bs4.BeautifulSoup'>
# one part ended and another is going to happed next
#
# Skip to content
# 日本語
# Deutsch
# English
# Español
# Português
# Français
# About Us
# Contact Us
# Customer Support
#
#           Log in
#
# Start free or get a demo
#
#
#
#
#
#
#
#
#
#           Marketing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Sales
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Service
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Website
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           The Hustle
#
#
#
#
#
#
#
#
#
#
# See all blogs
#
#
#
#
#
#
#
#           Marketing
#
# Read world-renowned marketing content to help grow your audience
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Sales
#
# Read best practices and examples of how to sell smarter
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Service
#
# Read expert tips on how to build a customer-first organization
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Website
#
# Read tips and tutorials on how to build better websites
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           The Hustle
#
# Read the latest business and tech news
#
#
#
#
#
#
#
#
# See all blogs
#
#
#
#
#           The Hustle
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           The Hustle
#
#
#
# Get the latest business and tech news in five minutes or less
#
#
#
#
#
#
#
#
#
#
#
#
#           HubSpot YouTube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           HubSpot Marketing YouTube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           My First Million YouTube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           HubSpot YouTube
#
#
#
# Learn everything you need to know about HubSpot and our products
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           HubSpot Marketing YouTube
#
#
#
# Stay on top of the latest marketing trends and tips
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           My First Million YouTube
#
#
#
#
#
# Join us as we brainstorm new business ideas based on current market trends
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           My First Million
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           The Hustle Daily
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Online Marketing Made Easy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Being Boss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           The Salesman
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Goal Digger
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Entrepreneurs on Fire
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           iDigress
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           MarTech Podcast
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Business Made Simple
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Success Story
#
#
#
#
#
#
#
#
#
#
# See all podcasts
#
#
#
#
#
#
#
#           My First Million
#
# Join us as we brainstorm new business ideas based on current market trends
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           The Hustle Daily
#
# A daily dose of irreverent and informative takes on business & tech news
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Online Marketing Made Easy
#
# Turn marketing strategies into step-by-step processes designed for success
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Being Boss
#
# Explore what it takes to be a creative business owner or side-hustler
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           The Salesman
#
# Listen to the world's most downloaded B2B sales podcast
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Goal Digger
#
#
#
# Get productivity tips and business hacks to design your dream career
#
#
#
#
#
#
#
#
#
#                           Entrepreneurs on Fire
#
#
#                           iDigress
#
#
#                           MarTech Podcast
#
#
#                           Business Made Simple
#
#
#                           Success Story
#
# See all podcasts
#
#
#
#
#           Ebooks, Guides & More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Free Courses & Certifications
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Ebooks, Guides & More
#
# Free ebooks, tools, and templates to help you grow
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Free Courses & Certifications
#
# Learn the latest business trends from leading experts with HubSpot Academy
#
#
#
#
#
#
#
#
#
# See pricing
#
#
#       Free HubSpot CRM
#
#
#
#
#       Overview of all products
#
#
#
#
#
#
#
#
#
#           Marketing Hub
#
# Marketing automation software. Free and premium plans
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Sales Hub
#
# Sales CRM software. Free and premium plans
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Service Hub
#
# Customer service software. Free and premium plans
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           CMS Hub
#
# Content management software. Free and premium plans
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Operations Hub
#
# Operations software. Free and premium plans
#
#
#
#
#
#
#
#
# Start free or get a demo
# Contact Sales
# Start free or get a demo
#
#
#
#
#           日本語
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Deutsch
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           English
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Español
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Português
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Français
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           About Us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Contact Us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Customer Support
#
#
#
#
#
#
#
#
#
#
#
#     Log in
#
# Sales
# Meredith Hart
#
#
#
#
#                                                         @meredithlhart
#
#
# Download the Famous Quotes Kit
# successful leaders
# entrepreneurs
#
# Canva
#
#
#
# Sales Quotes
#
#
#
#
#                     44 Inspirational Quotes About Change That Will Help You Think Differently
#
#
#                     Sales
#
#
#                     | 5 min read
#
#
#
#
#
#                     48 Quotes About Hard Work That’ll Help You Reach Your Goals
#
#
#                     Sales
#
#
#                     | 17 min read
#
# Get it now
#
#
#
#
#
#
# Free Meeting Scheduler App
# Social Media Tools
# Email Tracking Software
# Sales Email Automation
# Ads Software
# Email Marketing Software
# Lead Management Software
# Pipeline Management Tools
# Sales Email Templates
# Help Desk Software
# Free Online Form Builder
# Free Chatbot Builder
# Free Live Chat Software
# Marketing Analytics
# Free Landing Page Builder
# Website Grader
# Make My Persona
# Email Signature Generator
# Blog Ideas Generator
# Invoice Template Generator
# Marketing Plan Generator
# Free Business Templates
# Industry Benchmark Data
# Software Comparisons Library
# Website Themes & Templates
# About Us
# Careers
# Management Team
# Board of Directors
# Investor Relations
# Blog
# Contact Us
# Customer Support
# Join a Local User Group
# All Partner Programs
# Solutions Partner Program
# App Partner Program
# HubSpot for Startups
# Affiliate Program
#
# Facebook
#
#
# Instagram
#
#
# Youtube
#
#
# Twitter
#
#
# Linkedin
#
#
# Medium
#
#
#
#
#
#
#
#
#
# Legal Stuff
# Privacy Policy
# Security

# %%
# so there are mainly three type of objects were found inside the BeautifulSoup output
# and they are 
# tags 
# navigation_strings which are found in body of elements in html 
# and third type is of BeautifulSoup class 
print(len(a))
# Out:
# 187

# %%
# so we are going to use this data in order parse the html find modify it somehow such that 
# we will able to get the data in python and process it properly also 

print(htmlBeautified.title.get_text())

# with the use of DOM model 
# a=document.querySelectorAll("p")
# a[1].innerHTML
# 'Beginning of dialog window. Escape will cancel and close the window.'
# a[1].innerText
# 'Beginning of dialog window. Escape will cancel and close the window.'
# Out:
# The 100 Most Famous Quotes of All Time

# %%
# if i want classes of any element then i just have to de following 
b=htmlBeautified.find("p")
# it will return first p in that perticular document 
print(b)
# output will be : <p class="blog-nav-media-dropdown--mobile-header">Blogs</p>

# so i want to know the respected classes for the elements so i just do few things and we will set to go 
print(b['class']) #so i will give you all classes which are belngs to that perticular tag
# Out:
# <p class="blog-nav-media-dropdown--mobile-header">Blogs</p>
# ['blog-nav-media-dropdown--mobile-header']

# %%
# if i want to get all elements which have a perticular class then 
# say class is blog-nav-media-dropdown--mobile-header and want to find them 
# Syntax
# find_all("the tag you want to find",class_="the class which you want to check in tag which youhave given")

c=htmlBeautified.find_all("p",class_="blog-nav-media-dropdown--mobile-header")
print(c)
# so will get array as output and
# Out:
# [<p class="blog-nav-media-dropdown--mobile-header">Blogs</p>, <p class="blog-nav-media-dropdown--mobile-header">Newsletters</p>, <p class="blog-nav-media-dropdown--mobile-header">Videos</p>, <p class="blog-nav-media-dropdown--mobile-header">Podcasts</p>, <p class="blog-nav-media-dropdown--mobile-header">Resources</p>]

# %%
# get all links from all the anchor tags 

say as you know each tag has own inbuilt values like a tag has values like 
l=htmlBeautified.find_all("a");
links_dataset=[]
for i in range(len(l)):
    print(l[i])
    # links_dataset.append(l[i]["href"]);

# print(links_dataset)
# Out:
# <a class="blog-nav-menu__skip-link cl-button -tertiary -small" href="#blog-main-content">Skip to content</a>
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="ja">日本語</a>
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="de">Deutsch</a>
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="en">English</a>
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="es">Español</a>
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="pt">Português</a>
# <a class="cl-dropdown-menu-link -light redirect-link disabled" lang="fr">Français</a>
# <a class="cl-dropdown-menu-link -light redirect-link" href="https://www.hubspot.com/our-story">About Us</a>
# <a class="cl-dropdown-menu-link -light redirect-link" href="https://www.hubspot.com/company/contact">Contact Us</a>
# <a class="cl-dropdown-menu-link -light redirect-link" href="https://help.hubspot.com/">Customer Support</a>
# <a class="cl-navLink cl-link -light -hasSubNav link-item--anchor" data-logged-in-href="//app.hubspot.com/home" data-logged-in-text="Go to my account" href="//app.hubspot.com/home">
#           Log in
#         </a>
# <a class="blog-nav-hs-products__cta cl-button -small -primary" href="https://www.hubspot.com/products/get-started">Start free or get a demo</a>
# <a aria-label="HubSpot" class="blog-nav__logo" href="/" id="blog-nav__logo">
# <img alt="" class="blog-nav__logo-mobile" height="32" id="blog-nav__logo-mobile" loading="lazy" src="https://blog.hubspot.com/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/Icons/Sprocket.svg" width="30"/>
# <img alt="" class="blog-nav__logo-fixed" height="30" id="blog-nav__logo-fixed" loading="lazy" src="https://blog.hubspot.com/hubfs/assets/hubspot.com/web-team/WBZ/Blog%202021/Images/
# <a class="blog-nav-media-dropdown__stacked-list-item cl-navLink -light -regular" data-navigation-params="blognavcard-podcasts-martechpodcast" href="https://listen.hubspot.com/public/83/MarTech-Podcast-%2F%2F-Marketing-%2B-Technology-%3D-Business-Growth-5b86063f" target="_blank">
#                           MarTech Podcast
#                         </a>
# <a class="blog-nav-media-dropdown__stacked-list-item cl-navLink -light -regular" data-navigation-params="blognavcard-podcasts-businessmadesimple" href="https://listen.hubspot.com/public/83/Business-Made-Simple-with-Donald-Miller-6279d097" target="_blank">
#                           Business Made Simple
#                         </a>
# <a class="blog-nav-media-dropdown__stacked-list-item cl-navLink -light -regular" data-navigation-params="blognavcard-podcasts-successstory" href="https://listen.hubspot.com/public/83/Success-Story-with-Scott-D.-Clary-a3585e84" target="_blank">
#                           Success Story
#                         </a>
# <a class="cl-button -small -primary" href="https://www.hubspot.com/podcastnetwork" target="_blank">See all podcasts</a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" gtm="" href="https://www.hubspot.com/resources" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Ebooks, Guides &amp; More
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable blog-nav-card--media-card" data-navigation-params="blognavcard-resources-freecoursesandcertifications" gtm="" href="https://academy.hubspot.com/courses" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Free Courses &amp; Certifications
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# ...
# <a class="blog-nav-hs-products__cta cl-button -regular -primary" href="https://www.hubspot.com/products/get-started">Start free or get a demo</a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable disabled" gtm="" href="" lang="ja" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           日本語<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable disabled" gtm="" href="" lang="de" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Deutsch<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable disabled" gtm="" href="" lang="en" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           English<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable disabled" gtm="" href="" lang="es" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Español<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable disabled" gtm="" href="" lang="pt" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Português<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable disabled" gtm="" href="" lang="fr" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Français<svg class="cl-icon external-link-icon" height="14" width="14">
# <use xlink:href="#external-link"></use>
# </svg>
# </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable" gtm="" href="https://www.hubspot.com/our-story" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           About Us
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable" gtm="" href="https://www.hubspot.com/company/contact" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Contact Us
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="blog-nav-card cl-card -white -border -none -oz -hoverable" gtm="" href="https://help.hubspot.com/" target="_blank">
# <div class="blog-nav-card__body">
# <div class="blog-nav-card__content">
# <h4 class="blog-nav-card__content--title" gtm="">
#           Customer Support
#         </h4>
# <p class="blog-nav-card__content--description -small" gtm=""></p>
# </div>
# <div class="blog-nav-card__icon">
# <svg aria-hidden="true" class="cl-icon">
# <use xlink:href="#right"></use>
# </svg>
# </div>
# </div>
# </a>
# <a class="cl-navLink cl-link -light -hasSubNav link-item--anchor" data-logged-in-href="//app.hubspot.com/home" data-logged-in-text="Go to my account" href="//app.hubspot.com/home">
#     Log in
#     </a>
# <a href="https://blog.hubspot.com/sales">Sales</a>
# <a href="https://blog.hubspot.com/sales/author/meredith-hart">Meredith Hart</a>
# <a class="post-author-tag__twitter" href="https://twitter.com/meredithlhart" target="_blank">
#
#
#
#                                                         @meredithlhart
#
#                                                     </a>
# <a class="cta cta--primary cta--medium" href="https://offers.hubspot.com/250-famous-quotes?hubs_post-cta=author">Download the Famous Quotes Kit</a>
# <a href="https://blog.hubspot.com/sales/great-female-leader-quotes" rel="noopener" target="_blank">successful leaders</a>
# <a href="https://blog.hubspot.com/sales/steve-jobs-quotes" rel="noopener" target="_blank">entrepreneurs</a>
# <a data-linkorder="2" data-order="2" href="https://www.hubspot.com/company/management">Management Team</a>
# <a data-linkorder="3" data-order="3" href="https://www.hubspot.com/company/board-of-directors">Board of Directors</a>
# <a data-linkorder="4" data-order="4" href="https://ir.hubspot.com/?_ga=2.262843276.12874469.1592422655-430007000.1592422655">Investor Relations</a>
# <a data-linkorder="5" data-order="5" href="https://blog.hubspot.com">Blog</a>
# <a data-linkorder="6" data-order="6" href="https://www.hubspot.com/company/contact">Contact Us</a>
# <a data-linkorder="0" data-order="0" href="https://help.hubspot.com/">Customer Support</a>
# <a data-linkorder="1" data-order="1" href="https://www.hubspot.com/hubspot-user-groups">Join a Local User Group</a>
# <a data-linkorder="0" data-order="0" href="https://www.hubspot.com/partners">All Partner Programs</a>
# <a data-linkorder="1" data-order="1" href="https://www.hubspot.com/partners/solutions">Solutions Partner Program</a>
# <a data-linkorder="2" data-order="2" href="https://www.hubspot.com/partners/app">App Partner Program</a>
# <a data-linkorder="3" data-order="3" href="https://www.hubspot.com/startups/partners">HubSpot for Startups</a>
# <a data-linkorder="4" data-order="4" href="https://www.hubspot.com/partners/affiliates">Affiliate Program</a>
# <a class="hstc_facebook" href="https://www.facebook.com/hubspot" target="_blank">
# <i class="hsg-icon hsg-icon-facebook"></i><span class="hidden-social">Facebook</span>
# </a>
# <a class="hstc_instagram" href="https://www.instagram.com/hubspot/" target="_blank">
# <i class="hsg-icon hsg-icon-instagram"></i><span class="hidden-social">Instagram</span>
# </a>
# <a class="hstc_youtube" href="https://youtube.com/user/HubSpot" target="_blank">
# <i class="hsg-icon hsg-icon-youtube"></i><span class="hidden-social">Youtube</span>
# </a>
# <a class="hstc_twitter" href="https://twitter.com/HubSpot" target="_blank">
# <i class="hsg-icon hsg-icon-twitter"></i><span class="hidden-social">Twitter</span>
# </a>
# <a class="hstc_linkedin" href="https://www.linkedin.com/company/hubspot" target="_blank">
# <i class="hsg-icon hsg-icon-linkedin"></i><span class="hidden-social">Linkedin</span>
# </a>
# <a class="hstc_medium" href="https://medium.com/@HubSpot" target="_blank">
# <i class="hsg-icon hsg-icon-medium"></i><span class="hidden-social">Medium</span>
# </a>
# <a class="hsg-footer__app" href="https://apps.apple.com/us/app/hubspot/id1107711722">
# <img alt="Download on the App Store" class="homepage-mobile-footer-apple" loading="lazy" src="https://blog.hubspot.com/hubfs/app%20store%20high%20res.png"/>
# </a>
# <a class="hsg-footer__app" href="https://play.google.com/store/apps/details?id=com.hubspot.android&amp;hl=en_US">
# <img alt="Get it on Google Play" class="homepage-mobile-footer-google" loading="lazy" src="https://blog.hubspot.com/hubfs/google%20play%20high%20res.png"/>
# </a>
# <a href="//www.hubspot.com">
# <img alt="HubSpot" loading="lazy" src="https://blog.hubspot.com/hubfs/WBZ-1165%20Global%20Nav%20Redesign/Wordmark-White.svg"/></a>
# <a href="https://legal.hubspot.com/legal-stuff">Legal Stuff</a>
# <a href="https://legal.hubspot.com/privacy-policy">Privacy Policy</a>
# <a href="https://legal.hubspot.com/security">Security</a>
